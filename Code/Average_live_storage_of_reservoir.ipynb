# %%
# @title Imports
import pandas_datareader.data as web
import datetime
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
import math
import statistics
import statistics
 
import sklearn.metrics 
from sklearn.metrics import mean_squared_error

# %%
# @title reservoir levels

df_1=pd.read_csv('cholavaram_reservoir.csv')
df_2=pd.read_csv('poondi_reservoir.csv')
df3=pd.read_csv('chembarambakkam_reservoir.csv')
df4=pd.read_csv('redhills_reservoir.csv')
df_1.info()
plt.plot(df_1['Years'],df_1['Average'])
plt.plot(df_2['Years'],df_2['Average'])
plt.plot(df3['Years'],df3['Average'])
plt.plot(df4['Years'],df4['Average'])
plt.legend(['Cholavaram','Poondi','Chembarambakkam','Redhills'])
plt.xlabel('Years')
plt.ylabel('Water levels in MCM')
plt.title('Average live Storage levels across the  Reservoirs in Chennai ')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Years    10 non-null     int64
#  1   Average  10 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 288.0 bytes
# Text(0.5, 1.0, 'Average live Storage levels across the  Reservoirs in Chennai ')
